# %% [markdown]
# # 데이터 셋 하나로 합치기

# %% [markdown]
# ## 1. 데이터 불러오기

# %%
import pandas as pd

customers = pd.read_csv('./data/olist_customers_dataset.csv')
geolocation = pd.read_csv('./data/olist_geolocation_dataset.csv')
orders = pd.read_csv('./data/olist_orders_dataset.csv')
order_items = pd.read_csv('./data/olist_order_items_dataset.csv')
order_payments = pd.read_csv('./data/olist_order_payments_dataset.csv')
order_reviews = pd.read_csv('./data/olist_order_reviews_dataset.csv')
products = pd.read_csv('./data/olist_products_dataset.csv')
sellers = pd.read_csv('./data/olist_sellers_dataset.csv')
product_cat_name = pd.read_csv('./data/product_category_name_translation.csv')

# %% [markdown]
# ## 2. geolocation 특성 파악 및 처리
# - sellers 데이터 내 seller_zip_code_prefix와 customers 데이터 내 customer_zip_code_prefix는 서로 서로 다른 컬럼이므로 각각의 lat, lng 가 필요함
# - 또한 geolocation 데이터 내에는 중복된 zip_code_prefix와 geolocation_state가 존재하므로 평균값으로 lat, lng 대치
# - 따라서, geolocation 데이터 내에 해당되는 각 zip_code_prefix를 이용해 sellers와 customer의 새로운 lat, lng 컬럼 생성할 것

# %%
geolocation = geolocation.rename(columns={'geolocation_zip_code_prefix':'zip_code_prefix'})
sellers = sellers.rename(columns={'seller_zip_code_prefix':'zip_code_prefix'})
customers = customers.rename(columns={'customer_zip_code_prefix':'zip_code_prefix'})

# %%
sellers.seller_id.nunique(), len(sellers)
# Out:
# (3095, 3095)

# %%
geolocation.zip_code_prefix.nunique(), len(geolocation)
# Out:
# (19015, 1000163)

# %%
# zip_code_prefix가 중복되어있는지 확인하기 위함
geolocation.sort_values('zip_code_prefix')
# Out:
#          zip_code_prefix  geolocation_lat  geolocation_lng geolocation_city  \
# 1246                1001       -23.549292       -46.633559        sao paulo
# 429                 1001       -23.550498       -46.634338        sao paulo
# 1182                1001       -23.549779       -46.633957        sao paulo
# 1435                1001       -23.549292       -46.633559        sao paulo
# 326                 1001       -23.551427       -46.634074        sao paulo
# ...                  ...              ...              ...              ...
# 1000026            99980       -28.388679       -51.848863  david canabarro
# 999950             99980       -28.388400       -51.845225  david canabarro
# 1000002            99980       -28.388342       -51.845194  david canabarro
# 999864             99990       -28.329472       -51.769109        muliterno
# 999758             99990       -28.329718       -51.769615        muliterno
#
#         geolocation_state
# 1246                   SP
# 429                    SP
# 1182                   SP
# 1435                   SP
# 326                    SP
# ...                   ...
# 1000026                RS
# 999950                 RS
# 1000002                RS
# 999864                 RS
# 999758                 RS
#
# [1000163 rows x 5 columns]

# %%
geolocation.isnull().sum()
# Out:
# zip_code_prefix      0
# geolocation_lat      0
# geolocation_lng      0
# geolocation_city     0
# geolocation_state    0
# dtype: int64

# %% [markdown]
# #### lat, lng 평균값 적용

# %%
geolocation2 = geolocation.pivot_table(index='zip_code_prefix', values=['geolocation_lat','geolocation_lng'], aggfunc='mean').reset_index()
geolocation2
# Out:
#        zip_code_prefix  geolocation_lat  geolocation_lng
# 0                 1001       -23.550190       -46.634024
# 1                 1002       -23.548146       -46.634979
# 2                 1003       -23.548994       -46.635731
# 3                 1004       -23.549799       -46.634757
# 4                 1005       -23.549456       -46.636733
# ...                ...              ...              ...
# 19010            99960       -27.953722       -52.025511
# 19011            99965       -28.183372       -52.039850
# 19012            99970       -28.343766       -51.874689
# 19013            99980       -28.389129       -51.843836
# 19014            99990       -28.329595       -51.769362
#
# [19015 rows x 3 columns]

# %% [markdown]
# #### sellers와 geolocation 데이터 셋 merge 수행

# %%
from functools import reduce

sellers_geo = pd.merge(sellers, geolocation2, on='zip_code_prefix', how='inner')
sellers_geo = sellers_geo.rename(columns={'zip_code_prefix':'seller_zip_code_prefix', 'geolocation_lat':'seller_geolocation_lat', 'geolocation_lng':'seller_geolocation_lng'})
sellers_geo
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     e0eabded302882513ced4ea3eb0c7059                   13023
# 2     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 3     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 4     1d2732ef8321502ee8488e8bed1ab8cd                   20031
# ...                                ...                     ...
# 3083  f1fdf2d13186575751aa25876536d85c                    5314
# 3084  98dddbc4601dd4443ca174359b237166                   87111
# 3085  74871d19219c7d518d0090283e03c137                    4650
# 3086  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3087  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#          seller_city seller_state  seller_geolocation_lat  \
# 0           campinas           SP              -22.893848
# 1           campinas           SP              -22.893848
# 2         mogi guacu           SP              -22.383437
# 3     rio de janeiro           RJ              -22.909572
# 4     rio de janeiro           RJ              -22.909572
# ...              ...          ...                     ...
# 3083       sao paulo           SP              -23.530647
# 3084         sarandi           PR              -23.448041
# 3085       sao paulo           SP              -23.657851
# 3086         pelotas           RS              -31.751072
# 3087         taubate           SP              -23.012009
#
#       seller_geolocation_lng
# 0                 -47.061337
# 1                 -47.061337
# 2                 -46.947927
# 3                 -43.177703
# 4                 -43.177703
# ...                      ...
# 3083              -46.736453
# 3084              -51.869960
# 3085              -46.676925
# 3086              -52.323202
# 3087              -45.585652
#
# [3088 rows x 6 columns]

# %% [markdown]
# #### customers와 geolocation 데이터 셋 merge 수행

# %%
len(customers)
# Out:
# 99441

# %%
customers_geo = pd.merge(customers, geolocation2, on='zip_code_prefix', how='inner')
customers_geo = customers_geo.rename(columns={'zip_code_prefix':'customer_zip_code_prefix', 'geolocation_lat':'customer_geolocation_lat', 'geolocation_lng':'customer_geolocation_lng'})
customers_geo
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      5dca924cc99eea2dc5ba40d11ec5dd0f  2761fee7f378f0a8d7682d8a3fa07ab1
# 2      661897d4968f1b59bfff74c7eb2eb4fc  d06a495406b79cb8203ea21cc0942f8c
# 3      702b62324327ccba20f1be3465426437  8b3d988f330c1d1c3332ccd440c147b7
# 4      bdf997bae7ca819b0415f5174d6b4302  866755e25db620f8d7e81b351a15bb2f
# ...                                 ...                               ...
# 99158  0b7a30ba373aeb55cf28add5b5477956  8c8173e547e020f411aa55b2fceed861
# 99159  ff6b440b2465bfaef05c675efb48cd15  e38a27b979a552e019e297ecc22dc67b
# 99160  3f7029d9b98a47370cd5f3a97adcbccd  5894d202cc869b4ec460fce3c6ed8cb5
# 99161  d9110683c7a282144e9fc97660026a28  5cbfdb85ec130898108b32c50d619c39
# 99162  6fb4f2354f36e554ac80141e9128f528  3cc6f2e1b9199837fabb35ff4bf24884
#
#        customer_zip_code_prefix         customer_city customer_state  \
# 0                         14409                franca             SP
# 1                         14409                franca             SP
# 2                         14409                franca             SP
# 3                         14409                franca             SP
# 4                         14409                franca             SP
# ...                         ...                   ...            ...
# 99158                     87145              paicandu             PR
# 99159                     98860     eugenio de castro             RS
# 99160                      5538             sao paulo             SP
# 99161                     74980  aparecida de goiania             GO
# 99162                     99043           passo fundo             RS
#
#        customer_geolocation_lat  customer_geolocation_lng
# 0                    -20.498489                -47.396929
# 1                    -20.498489                -47.396929
# 2                    -20.498489                -47.396929
# 3                    -20.498489                -47.396929
# 4                    -20.498489                -47.396929
# ...                         ...                       ...
# 99158                -23.501806                -52.150926
# 99159                -28.527590                -54.145960
# 99160                -23.588483                -46.737908
# 99161                -16.822735                -49.248175
# 99162                -28.226596                -52.467505
#
# [99163 rows x 7 columns]

# %% [markdown]
# ## 3. 전체 데이터 합치기

# %%
from functools import reduce

df1 = reduce(lambda x,y: pd.merge(x,y, on='order_id', how='inner'), [order_items, orders, order_payments, order_reviews])
df2 = reduce(lambda x,y: pd.merge(x,y, on='customer_id', how='inner'), [df1, customers_geo])
df3 = reduce(lambda x,y: pd.merge(x,y, on='product_id', how='inner'), [df2, products])
df4 = reduce(lambda x,y: pd.merge(x,y, on='seller_id', how='inner'), [df3, sellers_geo])
df5 = reduce(lambda x,y: pd.merge(x,y, on='product_category_name', how='inner'), [df4, product_cat_name])
df5
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       130898c0987d1801452a8ed92a670612              1
# 2       532ed5e14e24ae1f0d735b91524b98b9              1
# 3       6f8c31653edb8c83e1a739408b5ff750              1
# 4       7d19f4ef4d04461989632411b7e588b9              1
# ...                                  ...            ...
# 115032  2c12150c742ae2fa48bc703964c16c5f              1
# 115033  2ef4a11b6e24fdfbb43b92cb5f95edff              1
# 115034  2ef4a11b6e24fdfbb43b92cb5f95edff              2
# 115035  9f7ba492c273ffac8f90a623b8eadd3b              1
# 115036  edcf1e1eeb52381be9388c90152be52d              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 2       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 3       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 4       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# ...                                  ...                               ...
# 115032  2b54fb9a4acf707537eb53eb2458c241  ef728fa1f17436c91ed1ccd03dcf9631
# 115033  9c313adb4b38a55b092f53f83f78be9e  ef728fa1f17436c91ed1ccd03dcf9631
# 115034  eacb104882d39ffb53140b1d1860a7c3  ef728fa1f17436c91ed1ccd03dcf9631
# 115035  5aa0d6ed4e6c0995d62090cd82cde89a  ef728fa1f17436c91ed1ccd03dcf9631
# 115036  6bb18295cc019bf3b6dc7c773411d530  04ee0ec01589969663ba5967c0e0bdc0
#
#         shipping_limit_date   price  freight_value  \
# 0       2017-09-19 09:45:35   58.90          13.29
# 1       2017-07-05 02:44:11   55.90          17.96
# 2       2018-05-23 10:56:25   64.90          18.33
# 3       2017-08-07 18:55:08   58.90          16.17
# 4       2017-08-16 22:05:11   58.90          13.29
# ...                     ...     ...            ...
# 115032  2018-08-02 17:50:12   57.90          19.60
# 115033  2018-07-30 09:17:39   19.00          12.86
# 115034  2018-07-30 09:17:39   39.90          12.87
# 115035  2018-08-28 03:24:24   11.90          12.79
# 115036  2018-08-27 11:50:47  289.49          24.83
#
#                              customer_id order_status  \
# 0       3ce436f183e68e07877b285a838db11a    delivered
# 1       e6eecc5a77de221464d1c4eaff0a9b64    delivered
# 2       4ef55bf80f711b372afebcb7c715344a    delivered
# 3       30407a72ad8b3f4df4d15369126b20c9    delivered
# 4       91a792fef70ecd8cc69d3c7feb3d12da    delivered
# ...                                  ...          ...
# 115032  ab0cf72dfe0538a63a57d6905ccb7b57    delivered
# 115033  ee1cfdc92e449920e25d3ca4ab4da4f6    delivered
# 115034  ee1cfdc92e449920e25d3ca4ab4da4f6    delivered
# 115035  c61336d6c835632048f973d2f2db598d    delivered
# 115036  ce2172509c4149d65212484eb761bc37    delivered
#
#        order_purchase_timestamp  ... product_weight_g product_length_cm  \
# 0           2017-09-13 08:59:02  ...            650.0              28.0
# 1           2017-06-28 11:52:20  ...            650.0              28.0
# 2           2018-05-18 10:25:53  ...            650.0              28.0
# 3           2017-08-01 18:38:42  ...            650.0              28.0
# 4           2017-08-10 21:48:40  ...            650.0              28.0
# ...                         ...  ...              ...               ...
# 115032      2018-07-28 17:55:27  ...           1000.0              25.0
# 115033      2018-07-23 18:35:14  ...            500.0              16.0
# 115034      2018-07-23 18:35:14  ...            500.0              21.0
# 115035      2018-08-23 12:31:37  ...            200.0              16.0
# 115036      2018-08-21 11:29:05  ...           1900.0              19.0
#
#        product_height_cm product_width_cm  seller_zip_code_prefix  \
# 0                    9.0             14.0                   27277
# 1                    9.0             14.0                   27277
# 2                    9.0             14.0                   27277
# 3                    9.0             14.0                   27277
# 4                    9.0             14.0                   27277
# ...                  ...              ...                     ...
# 115032              25.0             25.0                   17201
# 115033               6.0             16.0                   17201
# 115034               7.0             14.0                   17201
# 115035               6.0             16.0                   17201
# 115036              16.0             16.0                   95910
#
#           seller_city  seller_state  seller_geolocation_lat  \
# 0       volta redonda            SP              -22.496953
# 1       volta redonda            SP              -22.496953
# 2       volta redonda            SP              -22.496953
# 3       volta redonda            SP              -22.496953
# 4       volta redonda            SP              -22.496953
# ...               ...           ...                     ...
# 115032            jau            SP              -22.294360
# 115033            jau            SP              -22.294360
# 115034            jau            SP              -22.294360
# 115035            jau            SP              -22.294360
# 115036        lajeado            RS              -29.430824
#
#        seller_geolocation_lng  product_category_name_english
# 0                  -44.127492                     cool_stuff
# 1                  -44.127492                     cool_stuff
# 2                  -44.127492                     cool_stuff
# 3                  -44.127492                     cool_stuff
# 4                  -44.127492                     cool_stuff
# ...                       ...                            ...
# 115032             -48.558524          arts_and_craftmanship
# 115033             -48.558524          arts_and_craftmanship
# 115034             -48.558524          arts_and_craftmanship
# 115035             -48.558524          arts_and_craftmanship
# 115036             -51.993777          arts_and_craftmanship
#
# [115037 rows x 44 columns]

# %%
df5.columns
# Out:
# Index(['order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value', 'customer_id',
#        'order_status', 'order_purchase_timestamp', 'order_approved_at',
#        'order_delivered_carrier_date', 'order_delivered_customer_date',
#        'order_estimated_delivery_date', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value', 'review_id', 'review_score',
#        'review_comment_title', 'review_comment_message',
#        'review_creation_date', 'review_answer_timestamp', 'customer_unique_id',
#        'customer_zip_code_prefix', 'customer_city', 'customer_state',
#        'customer_geolocation_lat', 'customer_geolocation_lng',
#        'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'seller_zip_code_prefix', 'seller_city', 'seller_state',
#        'seller_geolocation_lat', 'seller_geolocation_lng',
#        'product_category_name_english'],
#       dtype='object')

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115037 entries, 0 to 115036
# Data columns (total 44 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       115037 non-null  object
#  1   order_item_id                  115037 non-null  int64
#  2   product_id                     115037 non-null  object
#  3   seller_id                      115037 non-null  object
#  4   shipping_limit_date            115037 non-null  object
#  5   price                          115037 non-null  float64
#  6   freight_value                  115037 non-null  float64
#  7   customer_id                    115037 non-null  object
#  8   order_status                   115037 non-null  object
#  9   order_purchase_timestamp       115037 non-null  object
#  10  order_approved_at              115023 non-null  object
#  11  order_delivered_carrier_date   113852 non-null  object
#  12  order_delivered_customer_date  112653 non-null  object
#  13  order_estimated_delivery_date  115037 non-null  object
#  14  payment_sequential             115037 non-null  int64
#  15  payment_type                   115037 non-null  object
#  16  payment_installments           115037 non-null  int64
#  17  payment_value                  115037 non-null  float64
#  18  review_id                      115037 non-null  object
#  19  review_score                   115037 non-null  int64
#  20  review_comment_title           13735 non-null   object
#  21  review_comment_message         48680 non-null   object
#  22  review_creation_date           115037 non-null  object
#  23  review_answer_timestamp        115037 non-null  object
#  24  customer_unique_id             115037 non-null  object
#  25  customer_zip_code_prefix       115037 non-null  int64
#  26  customer_city                  115037 non-null  object
#  27  customer_state                 115037 non-null  object
#  28  customer_geolocation_lat       115037 non-null  float64
#  29  customer_geolocation_lng       115037 non-null  float64
#  30  product_category_name          115037 non-null  object
#  31  product_name_lenght            115037 non-null  float64
#  32  product_description_lenght     115037 non-null  float64
#  33  product_photos_qty             115037 non-null  float64
#  34  product_weight_g               115036 non-null  float64
#  35  product_length_cm              115036 non-null  float64
#  36  product_height_cm              115036 non-null  float64
#  37  product_width_cm               115036 non-null  float64
#  38  seller_zip_code_prefix         115037 non-null  int64
#  39  seller_city                    115037 non-null  object
#  40  seller_state                   115037 non-null  object
#  41  seller_geolocation_lat         115037 non-null  float64
#  42  seller_geolocation_lng         115037 non-null  float64
#  43  product_category_name_english  115037 non-null  object
# dtypes: float64(14), int64(6), object(24)
# memory usage: 39.5+ MB

# %%
df5.to_csv("olist_total.csv", index = False)

# %%
pd.read_csv('olist_total.csv')
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       130898c0987d1801452a8ed92a670612              1
# 2       532ed5e14e24ae1f0d735b91524b98b9              1
# 3       6f8c31653edb8c83e1a739408b5ff750              1
# 4       7d19f4ef4d04461989632411b7e588b9              1
# ...                                  ...            ...
# 115032  2c12150c742ae2fa48bc703964c16c5f              1
# 115033  2ef4a11b6e24fdfbb43b92cb5f95edff              1
# 115034  2ef4a11b6e24fdfbb43b92cb5f95edff              2
# 115035  9f7ba492c273ffac8f90a623b8eadd3b              1
# 115036  edcf1e1eeb52381be9388c90152be52d              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 2       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 3       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 4       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# ...                                  ...                               ...
# 115032  2b54fb9a4acf707537eb53eb2458c241  ef728fa1f17436c91ed1ccd03dcf9631
# 115033  9c313adb4b38a55b092f53f83f78be9e  ef728fa1f17436c91ed1ccd03dcf9631
# 115034  eacb104882d39ffb53140b1d1860a7c3  ef728fa1f17436c91ed1ccd03dcf9631
# 115035  5aa0d6ed4e6c0995d62090cd82cde89a  ef728fa1f17436c91ed1ccd03dcf9631
# 115036  6bb18295cc019bf3b6dc7c773411d530  04ee0ec01589969663ba5967c0e0bdc0
#
#         shipping_limit_date   price  freight_value  \
# 0       2017-09-19 09:45:35   58.90          13.29
# 1       2017-07-05 02:44:11   55.90          17.96
# 2       2018-05-23 10:56:25   64.90          18.33
# 3       2017-08-07 18:55:08   58.90          16.17
# 4       2017-08-16 22:05:11   58.90          13.29
# ...                     ...     ...            ...
# 115032  2018-08-02 17:50:12   57.90          19.60
# 115033  2018-07-30 09:17:39   19.00          12.86
# 115034  2018-07-30 09:17:39   39.90          12.87
# 115035  2018-08-28 03:24:24   11.90          12.79
# 115036  2018-08-27 11:50:47  289.49          24.83
#
#                              customer_id order_status  \
# 0       3ce436f183e68e07877b285a838db11a    delivered
# 1       e6eecc5a77de221464d1c4eaff0a9b64    delivered
# 2       4ef55bf80f711b372afebcb7c715344a    delivered
# 3       30407a72ad8b3f4df4d15369126b20c9    delivered
# 4       91a792fef70ecd8cc69d3c7feb3d12da    delivered
# ...                                  ...          ...
# 115032  ab0cf72dfe0538a63a57d6905ccb7b57    delivered
# 115033  ee1cfdc92e449920e25d3ca4ab4da4f6    delivered
# 115034  ee1cfdc92e449920e25d3ca4ab4da4f6    delivered
# 115035  c61336d6c835632048f973d2f2db598d    delivered
# 115036  ce2172509c4149d65212484eb761bc37    delivered
#
#        order_purchase_timestamp  ... product_weight_g product_length_cm  \
# 0           2017-09-13 08:59:02  ...            650.0              28.0
# 1           2017-06-28 11:52:20  ...            650.0              28.0
# 2           2018-05-18 10:25:53  ...            650.0              28.0
# 3           2017-08-01 18:38:42  ...            650.0              28.0
# 4           2017-08-10 21:48:40  ...            650.0              28.0
# ...                         ...  ...              ...               ...
# 115032      2018-07-28 17:55:27  ...           1000.0              25.0
# 115033      2018-07-23 18:35:14  ...            500.0              16.0
# 115034      2018-07-23 18:35:14  ...            500.0              21.0
# 115035      2018-08-23 12:31:37  ...            200.0              16.0
# 115036      2018-08-21 11:29:05  ...           1900.0              19.0
#
#        product_height_cm product_width_cm  seller_zip_code_prefix  \
# 0                    9.0             14.0                   27277
# 1                    9.0             14.0                   27277
# 2                    9.0             14.0                   27277
# 3                    9.0             14.0                   27277
# 4                    9.0             14.0                   27277
# ...                  ...              ...                     ...
# 115032              25.0             25.0                   17201
# 115033               6.0             16.0                   17201
# 115034               7.0             14.0                   17201
# 115035               6.0             16.0                   17201
# 115036              16.0             16.0                   95910
#
#           seller_city  seller_state  seller_geolocation_lat  \
# 0       volta redonda            SP              -22.496953
# 1       volta redonda            SP              -22.496953
# 2       volta redonda            SP              -22.496953
# 3       volta redonda            SP              -22.496953
# 4       volta redonda            SP              -22.496953
# ...               ...           ...                     ...
# 115032            jau            SP              -22.294360
# 115033            jau            SP              -22.294360
# 115034            jau            SP              -22.294360
# 115035            jau            SP              -22.294360
# 115036        lajeado            RS              -29.430824
#
#        seller_geolocation_lng  product_category_name_english
# 0                  -44.127492                     cool_stuff
# 1                  -44.127492                     cool_stuff
# 2                  -44.127492                     cool_stuff
# 3                  -44.127492                     cool_stuff
# 4                  -44.127492                     cool_stuff
# ...                       ...                            ...
# 115032             -48.558524          arts_and_craftmanship
# 115033             -48.558524          arts_and_craftmanship
# 115034             -48.558524          arts_and_craftmanship
# 115035             -48.558524          arts_and_craftmanship
# 115036             -51.993777          arts_and_craftmanship
#
# [115037 rows x 44 columns]
